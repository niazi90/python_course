# %%
file=open("demo.txt","r")
print(file.read())
file.close()
# Out:
# This text is  overwrite  and replace text

# %%
file=open("demo.txt","w")
print(file.write("This text is  overwrite  and replace text"))
file.close()
# Out:
# 41
