# %%
class Animal:
    def speak(self):
        print("some sound")
class Dog(Animal):
    pass
dog1=Dog()
dog1.speak()
# Out:
# some sound

# %%
class Dog(Animal):
    def bark(self):
        print("wolf")
childdog=Dog()
childdog.bark()
childdog.speak()
# Out:
# wolf
# some sound
