# %%
with open('demo.txt','r')as file:
    data=file.read()
    print(data)
# Out:
# This text is  overwrite  and replace text
#  this is new line added
#  this is new line added

# %% [markdown]
# using manager other statement
# 1. open()    ====>  reading/writing file
# 2. tempfile.TemporaryFile()/NamedTemporaryFile  ====>   create temporary and delete automatically
# 3. zipfile.ZipFile()      ====>  open zip file reading and writing
# 4. contextlib.ExistStack   ====>  manage multiple file at once easily
# 5. pathlib.Path().open()  ====>  modern ,object oriented file opening va pathlib
