# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB 435.7 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/9.9 MB 653.6 kB/s eta 0:00:16
#     --------------------------------------- 0.2/9.9 MB 1.2 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/9.9 MB 1.6 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.9 MB 1.6 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.9 MB 1.6 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/9.9 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/9.9 MB 1.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/9.9 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.9 MB 1.4 MB/s eta 0:00:07
# ...

# %%
import pandas as pd 
s=pd.Series([2,3,44,90,77,44],index=['a','b','c','d','e','f'])
print(s)
# Out:
# a     2
# b     3
# c    44
# d    90
# e    77
# f    44
# dtype: int64

# %%
print("values are:",s.values)
print("index are:",s.index)
print("data types are:",s.dtype)
# Out:
# values are: [ 2  3 44 90 77 44]
# index are: Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='str')
# data types are: int64
# head are: <bound method NDFrame.head of a     2
# b     3
# c    44
# d    90
# e    77
# f    44
# dtype: int64>
# tail  are: <bound method NDFrame.tail of a     2
# b     3
# c    44
# d    90
# e    77
# f    44
# dtype: int64>

# %%
print("head are:",s.head)
# Out:
# head are: <bound method NDFrame.head of a     2
# b     3
# c    44
# d    90
# e    77
# f    44
# dtype: int64>

# %%
print("tail  are:",s.tail)
# Out:
# tail  are: <bound method NDFrame.tail of a     2
# b     3
# c    44
# d    90
# e    77
# f    44
# dtype: int64>

# %%
print(s.value_counts())
# Out:
# 44    2
# 2     1
# 3     1
# 90    1
# 77    1
# Name: count, dtype: int64
