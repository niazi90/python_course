# %%
import pandas as pd

# %%
df=pd.DataFrame({
    'Category':['Electronic','Furniture ','Home-Appliance','HOME']
})
print(df)
# Out:
#          Category
# 0      Electronic
# 1      Furniture
# 2  Home-Appliance
# 3            HOME

# %%
df['Category_clean']=df['Category'].str.strip().str.lower()
print(df)
# Out:
#          Category  Category_clean
# 0      Electronic      electronic
# 1      Furniture        furniture
# 2  Home-Appliance  home-appliance
# 3            HOME            home

# %%
df['Category_clean']=df['Category'].str.replace('-',' ')
print(df)
# Out:
#          Category  Category_clean
# 0      Electronic      Electronic
# 1      Furniture       Furniture
# 2  Home-Appliance  Home Appliance
# 3            HOME            HOME
