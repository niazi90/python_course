# %% [markdown]
# DataFrame is two dimensional  row and column
# similar to SQL or spread sheet
# can hold different data type

# %%
import pandas as pd

# %%
name={
    'Name':['Azhar iqbal','Ali khan','Rufiullah khan'],
    'age':[22,23,24],
    'city':['Peshawar','Islamabad','Karachi']
}
df=pd.DataFrame(name)
print(df)
# Out:
#              Name  age       city
# 0     Azhar iqbal   22   Peshawar
# 1        Ali khan   23  Islamabad
# 2  Rufiullah khan   24    Karachi

# %%
data=pd.read_csv('retail_data.csv')
print('info:\n',data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        15 non-null     str
#  1   Catagoery   15 non-null     str
#  2   Sales       15 non-null     float64
#  3   Quantities  15 non-null     float64
#  4   Profit      15 non-null     float64
#  5   Regin       15 non-null     str
# dtypes: float64(3), str(3)
# memory usage: 852.0 bytes
# info:
#  None

# %%
print('\nShape:',data.shape)
# Out:
# Shape: (15, 6)

# %%
print('Datatypes:\n',data.dtypes)
# Out:
# Datatypes:
#  Date              str
# Catagoery         str
# Sales         float64
# Quantities    float64
# Profit        float64
# Regin             str
# dtype: object

# %%
print('\nstatistacal summary:\n',data.describe())
# Out:
# statistacal summary:
#                Sales   Quantities       Profit
# count     15.000000    15.000000    15.000000
# mean   20537.666668  -157.857143  -659.329200
# std    15883.041458   620.699131  3579.910895
# min     1427.666667 -1122.607143 -5518.958800
# 25%     8252.666667  -640.232143 -3089.144000
# 50%    17807.666670  -157.857143  -659.329200
# 75%    30267.500000   284.500000   342.467000
# max    53444.000000   898.000000  6732.900000
